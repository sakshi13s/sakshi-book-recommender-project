# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshi13s/sakshi-book-recommender-project/blob/main/Book_Recommender_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the 3 dataset of books, users and book ratings
# !gdown https://drive.google.com/uc?id=16b-VgOnuvFI047G1cFlNU3GPf4z0il7f
# !unzip Books.csv.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=16b-VgOnuvFI047G1cFlNU3GPf4z0il7f
# To: /content/Books.csv.zip
# 100% 15.6M/15.6M [00:00<00:00, 37.0MB/s]
# Archive:  Books.csv.zip
#   inflating: Books.csv

# %%
# !gdown https://drive.google.com/uc?id=1zJuz4mGvYuV1gSTXTeNTfjUP4FH4b8OU
# !unzip Users.csv.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1zJuz4mGvYuV1gSTXTeNTfjUP4FH4b8OU
# To: /content/Users.csv.zip
# 100% 2.98M/2.98M [00:00<00:00, 193MB/s]
# Archive:  Users.csv.zip
#   inflating: Users.csv

# %%
# !gdown https://drive.google.com/uc?id=1_RzfJ7NvrWcrVLFTkKId6DfxS6f9wHfT
# !unzip Ratings.csv.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1_RzfJ7NvrWcrVLFTkKId6DfxS6f9wHfT
# To: /content/Ratings.csv.zip
# 100% 6.41M/6.41M [00:00<00:00, 18.0MB/s]
# Archive:  Ratings.csv.zip
#   inflating: Ratings.csv

# %%
import numpy as np
import pandas as pd

# %%
books = pd.read_csv('Books.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#books dataframe
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
books.shape
# Out:
# (271360, 8)

# %%
users = pd.read_csv('Users.csv')

# %%
#users dataframe
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
users.shape
# Out:
# (278858, 3)

# %%
ratings = pd.read_csv('Ratings.csv')

# %%
#ratings dataframe
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings.shape
# Out:
# (1149780, 3)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
#finding missing values but age is not required for recommendation
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
users.duplicated().sum()
# Out:
# 0

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
ratings.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Popularity Based (Best Sellers)

# %%
#merge ratings and books dataframe on the basis of ISBN
ratings.merge(books, on='ISBN')
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1           2313  034545104X            5
# 2           6543  034545104X            0
# 3           8680  034545104X            5
# 4          10314  034545104X            9
# ...          ...         ...          ...
# 1031131   276688  0517145553            0
# 1031132   276688  1575660792            7
# 1031133   276690  0590907301            0
# 1031134   276704  0679752714            0
# 1031135   276704  0806917695            5
#
#                                                 Book-Title      Book-Author  \
# 0                                     Flesh Tones: A Novel       M. J. Rose
# 1                                     Flesh Tones: A Novel       M. J. Rose
# 2                                     Flesh Tones: A Novel       M. J. Rose
# 3                                     Flesh Tones: A Novel       M. J. Rose
# ...

# %%
ratings.merge(books, on='ISBN').shape
# Out:
# (1031136, 10)

# %%
#storing the new dataframe in a new variable
ratings_with_bookname = ratings.merge(books, on='ISBN')

# %%
ratings_with_bookname
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1           2313  034545104X            5
# 2           6543  034545104X            0
# 3           8680  034545104X            5
# 4          10314  034545104X            9
# ...          ...         ...          ...
# 1031131   276688  0517145553            0
# 1031132   276688  1575660792            7
# 1031133   276690  0590907301            0
# 1031134   276704  0679752714            0
# 1031135   276704  0806917695            5
#
#                                                 Book-Title      Book-Author  \
# 0                                     Flesh Tones: A Novel       M. J. Rose
# 1                                     Flesh Tones: A Novel       M. J. Rose
# 2                                     Flesh Tones: A Novel       M. J. Rose
# 3                                     Flesh Tones: A Novel       M. J. Rose
# ...

# %%
#to find the avg votes and consider only those books which have number of ratings >250
ratings_with_bookname.groupby('Book-Title').count()
# Out:
#                                                     User-ID  ISBN  \
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...        4     4
#  Always Have Popsicles                                    1     1
#  Apple Magic (The Collector's series)                     1     1
#  Ask Lily (Young Women of Faith: Lily Series, B...        1     1
#  Beyond IBM: Leadership Marketing and Finance f...        1     1
# ...                                                     ...   ...
# Ã?Â?lpiraten.                                             2     2
# Ã?Â?rger mit Produkt X. Roman.                            4     4
# Ã?Â?sterlich leben.                                       1     1
# Ã?Â?stlich der Berge.                                     3     3
# Ã?Â?thique en toc                                         2     2
#
#                                                     Book-Rating  Book-Author  \
# Book-Title
# ...

# %%
ratings_with_bookname.groupby('Book-Title').count()['Book-Rating']
# Out:
# Book-Title
#  A Light in the Storm: The Civil War Diary of Amelia Martin, Fenwick Island, Delaware, 1861 (Dear America)    4
#  Always Have Popsicles                                                                                        1
#  Apple Magic (The Collector's series)                                                                         1
#  Ask Lily (Young Women of Faith: Lily Series, Book 5)                                                         1
#  Beyond IBM: Leadership Marketing and Finance for the 1990s                                                   1
#                                                                                                              ..
# Ã?Â?lpiraten.                                                                                                 2
# Ã?Â?rger mit Produkt X. Roman.                                                                                4
# ...

# %%
ratings_with_bookname.groupby('Book-Title').count()['Book-Rating'].reset_index()
# Out:
#                                                Book-Title  Book-Rating
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %%
#new dataframe
num_rating_df = ratings_with_bookname.groupby('Book-Title').count()['Book-Rating'].reset_index()

# %%
num_rating_df.rename(columns={'Book-Rating': 'num_of_ratings'}, inplace=True)

# %%
num_rating_df
# Out:
#                                                Book-Title  num_of_ratings
# 0        A Light in the Storm: The Civil War Diary of ...               4
# 1                                   Always Have Popsicles               1
# 2                    Apple Magic (The Collector's series)               1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...               1
# 4        Beyond IBM: Leadership Marketing and Finance ...               1
# ...                                                   ...             ...
# 241066                                      Ã?Â?lpiraten.               2
# 241067                     Ã?Â?rger mit Produkt X. Roman.               4
# 241068                                Ã?Â?sterlich leben.               1
# 241069                              Ã?Â?stlich der Berge.               3
# 241070                                  Ã?Â?thique en toc               2
#
# [241071 rows x 2 columns]

# %%
#dataframe which contains avg rating of books
avg_rating_df = ratings_with_bookname.groupby('Book-Title').mean()['Book-Rating'].reset_index()

# %%
avg_rating_df.rename(columns={'Book-Rating': 'avg_ratings'}, inplace=True)

# %%
avg_rating_df
# Out:
#                                                Book-Title  avg_ratings
# 0        A Light in the Storm: The Civil War Diary of ...     2.250000
# 1                                   Always Have Popsicles     0.000000
# 2                    Apple Magic (The Collector's series)     0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...     8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...     0.000000
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.     0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.     5.250000
# 241068                                Ã?Â?sterlich leben.     7.000000
# 241069                              Ã?Â?stlich der Berge.     2.666667
# 241070                                  Ã?Â?thique en toc     4.000000
#
# [241071 rows x 2 columns]

# %%
popular_df = num_rating_df.merge(avg_rating_df, on='Book-Title')

# %%
popular_df
# Out:
#                                                Book-Title  num_of_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...               4
# 1                                   Always Have Popsicles               1
# 2                    Apple Magic (The Collector's series)               1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...               1
# 4        Beyond IBM: Leadership Marketing and Finance ...               1
# ...                                                   ...             ...
# 241066                                      Ã?Â?lpiraten.               2
# 241067                     Ã?Â?rger mit Produkt X. Roman.               4
# 241068                                Ã?Â?sterlich leben.               1
# 241069                              Ã?Â?stlich der Berge.               3
# 241070                                  Ã?Â?thique en toc               2
#
#         avg_ratings
# 0          2.250000
# 1          0.000000
# ...

# %%
#considering only those books which have a minimum rating of 250
popular_df[popular_df['num_of_ratings']>=250]
# Out:
#                                                Book-Title  num_of_ratings  \
# 764                                                  1984             284
# 818                                   1st to Die: A Novel             509
# 1048                                           2nd Chance             356
# 1760                                   A Bend in the Road             346
# 2281    A Child Called \It\": One Child's Courage to S...             265
# ...                                                   ...             ...
# 233850                           White Oleander : A Novel             387
# 233851       White Oleander : A Novel (Oprah's Book Club)             356
# 234740  Wicked: The Life and Times of the Wicked Witch...             326
# 234951                                        Wild Animus            2502
# 240860                                \O\" Is for Outlaw"             269
#
#         avg_ratings
# 764        4.454225
# 818        3.575639
# ...

# %%
popular_df[popular_df['num_of_ratings']>=250].sort_values('avg_ratings', ascending=False)
# Out:
#                                                Book-Title  num_of_ratings  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)             428
# 80422        Harry Potter and the Goblet of Fire (Book 4)             387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)             278
# 80426   Harry Potter and the Order of the Phoenix (Boo...             347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)             556
# ...                                                   ...             ...
# 227701       Vinegar Hill (Oprah's Book Club (Paperback))             265
# 233635                                           Whispers             286
# 143377                                  Presumed Innocent             294
# 94382                                        Isle of Dogs             288
# 234951                                        Wild Animus            2502
#
#         avg_ratings
# 80434      5.852804
# 80422      5.824289
# ...

# %%
#getting top 21 most popular books
popular_df[popular_df['num_of_ratings']>=250].sort_values('avg_ratings', ascending=False).head(21)
# Out:
#                                                Book-Title  num_of_ratings  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)             428
# 80422        Harry Potter and the Goblet of Fire (Book 4)             387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)             278
# 80426   Harry Potter and the Order of the Phoenix (Boo...             347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)             556
# 191612  The Hobbit : The Enchanting Prelude to The Lor...             281
# 187377  The Fellowship of the Ring (The Lord of the Ri...             368
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...             575
# 211384     The Two Towers (The Lord of the Rings, Part 2)             260
# 219741                              To Kill a Mockingbird             510
# 183573                                  The Da Vinci Code             898
# 187880                 The Five People You Meet in Heaven             430
# ...

# %%
popular_df = popular_df[popular_df['num_of_ratings']>=250].sort_values('avg_ratings', ascending=False).head(21)

# %%
popular_df
# Out:
#                                                Book-Title  num_of_ratings  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)             428
# 80422        Harry Potter and the Goblet of Fire (Book 4)             387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)             278
# 80426   Harry Potter and the Order of the Phoenix (Boo...             347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)             556
# 191612  The Hobbit : The Enchanting Prelude to The Lor...             281
# 187377  The Fellowship of the Ring (The Lord of the Ri...             368
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...             575
# 211384     The Two Towers (The Lord of the Rings, Part 2)             260
# 219741                              To Kill a Mockingbird             510
# 183573                                  The Da Vinci Code             898
# 187880                 The Five People You Meet in Heaven             430
# ...

# %%
popular_df.merge(books, on='Book-Title')
# Out:
#                                            Book-Title  num_of_ratings  \
# 0   Harry Potter and the Prisoner of Azkaban (Book 3)             428
# 1   Harry Potter and the Prisoner of Azkaban (Book 3)             428
# 2   Harry Potter and the Prisoner of Azkaban (Book 3)             428
# 3        Harry Potter and the Goblet of Fire (Book 4)             387
# 4        Harry Potter and the Goblet of Fire (Book 4)             387
# ..                                                ...             ...
# 84  Stupid White Men ...and Other Sorry Excuses fo...             283
# 85  Tuesdays with Morrie: An Old Man, a Young Man,...             493
# 86  Tuesdays with Morrie: An Old Man, a Young Man,...             493
# 87  Tuesdays with Morrie: An Old Man, a Young Man,...             493
# 88                The Red Tent (Bestselling Backlist)             723
#
#     avg_ratings        ISBN    Book-Author Year-Of-Publication  \
# ...

# %%
popular_df.merge(books, on='Book-Title').drop_duplicates('Book-Title')
# Out:
#                                            Book-Title  num_of_ratings  \
# 0   Harry Potter and the Prisoner of Azkaban (Book 3)             428
# 3        Harry Potter and the Goblet of Fire (Book 4)             387
# 5      Harry Potter and the Sorcerer's Stone (Book 1)             278
# 9   Harry Potter and the Order of the Phoenix (Boo...             347
# 13   Harry Potter and the Chamber of Secrets (Book 2)             556
# 16  The Hobbit : The Enchanting Prelude to The Lor...             281
# 17  The Fellowship of the Ring (The Lord of the Ri...             368
# 26  Harry Potter and the Sorcerer's Stone (Harry P...             575
# 28     The Two Towers (The Lord of the Rings, Part 2)             260
# 39                              To Kill a Mockingbird             510
# 47                                  The Da Vinci Code             898
# 53                 The Five People You Meet in Heaven             430
# ...

# %%
popular_df.merge(books, on='Book-Title').drop_duplicates('Book-Title').shape
# Out:
# (21, 10)

# %%
popular_df.merge(books, on='Book-Title').drop_duplicates('Book-Title')[['Book-Title', 'Book-Author', 'Image-URL-M', 'num_of_ratings', 'avg_ratings']]
# Out:
#                                            Book-Title         Book-Author  \
# 0   Harry Potter and the Prisoner of Azkaban (Book 3)       J. K. Rowling
# 3        Harry Potter and the Goblet of Fire (Book 4)       J. K. Rowling
# 5      Harry Potter and the Sorcerer's Stone (Book 1)       J. K. Rowling
# 9   Harry Potter and the Order of the Phoenix (Boo...       J. K. Rowling
# 13   Harry Potter and the Chamber of Secrets (Book 2)       J. K. Rowling
# 16  The Hobbit : The Enchanting Prelude to The Lor...      J.R.R. TOLKIEN
# 17  The Fellowship of the Ring (The Lord of the Ri...      J.R.R. TOLKIEN
# 26  Harry Potter and the Sorcerer's Stone (Harry P...       J. K. Rowling
# 28     The Two Towers (The Lord of the Rings, Part 2)      J.R.R. TOLKIEN
# 39                              To Kill a Mockingbird          Harper Lee
# 47                                  The Da Vinci Code           Dan Brown
# 53                 The Five People You Meet in Heaven         Mitch Albom
# ...

# %%
popular_df = popular_df.merge(books, on='Book-Title').drop_duplicates('Book-Title')[['Book-Title', 'Book-Author', 'Image-URL-M', 'num_of_ratings', 'avg_ratings']]

# %%
popular_df
# Out:
#                                            Book-Title         Book-Author  \
# 0   Harry Potter and the Prisoner of Azkaban (Book 3)       J. K. Rowling
# 3        Harry Potter and the Goblet of Fire (Book 4)       J. K. Rowling
# 5      Harry Potter and the Sorcerer's Stone (Book 1)       J. K. Rowling
# 9   Harry Potter and the Order of the Phoenix (Boo...       J. K. Rowling
# 13   Harry Potter and the Chamber of Secrets (Book 2)       J. K. Rowling
# 16  The Hobbit : The Enchanting Prelude to The Lor...      J.R.R. TOLKIEN
# 17  The Fellowship of the Ring (The Lord of the Ri...      J.R.R. TOLKIEN
# 26  Harry Potter and the Sorcerer's Stone (Harry P...       J. K. Rowling
# 28     The Two Towers (The Lord of the Rings, Part 2)      J.R.R. TOLKIEN
# 39                              To Kill a Mockingbird          Harper Lee
# 47                                  The Da Vinci Code           Dan Brown
# 53                 The Five People You Meet in Heaven         Mitch Albom
# ...

# %%
popular_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21 entries, 0 to 88
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Book-Title      21 non-null     object
#  1   Book-Author     21 non-null     object
#  2   Image-URL-M     21 non-null     object
#  3   num_of_ratings  21 non-null     int64
#  4   avg_ratings     21 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 1008.0+ bytes

# %% [markdown]
# ## Collaborative Filtering Based

# %%
ratings_with_bookname
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1           2313  034545104X            5
# 2           6543  034545104X            0
# 3           8680  034545104X            5
# 4          10314  034545104X            9
# ...          ...         ...          ...
# 1031131   276688  0517145553            0
# 1031132   276688  1575660792            7
# 1031133   276690  0590907301            0
# 1031134   276704  0679752714            0
# 1031135   276704  0806917695            5
#
#                                                 Book-Title      Book-Author  \
# 0                                     Flesh Tones: A Novel       M. J. Rose
# 1                                     Flesh Tones: A Novel       M. J. Rose
# 2                                     Flesh Tones: A Novel       M. J. Rose
# 3                                     Flesh Tones: A Novel       M. J. Rose
# ...

# %%
#to get information about which user has rated how many books
ratings_with_bookname.groupby('User-ID').count()
# Out:
#          ISBN  Book-Rating  Book-Title  Book-Author  Year-Of-Publication  \
# User-ID
# 2           1            1           1            1                    1
# 8          17           17          17           17                   17
# 9           3            3           3            3                    3
# 10          1            1           1            1                    1
# 12          1            1           1            1                    1
# ...       ...          ...         ...          ...                  ...
# 278846      1            1           1            1                    1
# 278849      4            4           4            4                    4
# 278851     23           23          23           23                   23
# 278852      1            1           1            1                    1
# 278854      8            8           8            8                    8
#
#          Publisher  Image-URL-S  Image-URL-M  Image-URL-L
# User-ID
# ...

# %%
ratings_with_bookname.groupby('User-ID').count()['Book-Rating']
# Out:
# User-ID
# 2          1
# 8         17
# 9          3
# 10         1
# 12         1
#           ..
# 278846     1
# 278849     4
# 278851    23
# 278852     1
# 278854     8
# Name: Book-Rating, Length: 92106, dtype: int64

# %%
#considering only those users who have rated more than 200 books
ratings_with_bookname.groupby('User-ID').count()['Book-Rating'] > 200
# Out:
# User-ID
# 2         False
# 8         False
# 9         False
# 10        False
# 12        False
#           ...
# 278846    False
# 278849    False
# 278851    False
# 278852    False
# 278854    False
# Name: Book-Rating, Length: 92106, dtype: bool

# %%
x = ratings_with_bookname.groupby('User-ID').count()['Book-Rating'] > 200

# %%
x[x]
# Out:
# User-ID
# 254       True
# 2276      True
# 2766      True
# 2977      True
# 3363      True
#           ...
# 274308    True
# 275970    True
# 277427    True
# 277639    True
# 278418    True
# Name: Book-Rating, Length: 811, dtype: bool

# %%
x[x].index
# Out:
# Int64Index([   254,   2276,   2766,   2977,   3363,   4017,   4385,   6251,
#               6323,   6543,
#             ...
#             271705, 273979, 274004, 274061, 274301, 274308, 275970, 277427,
#             277639, 278418],
#            dtype='int64', name='User-ID', length=811)

# %%
y = x[x].index

# %%
ratings_with_bookname['User-ID'].isin(y)
# Out:
# 0          False
# 1          False
# 2           True
# 3          False
# 4          False
#            ...
# 1031131    False
# 1031132    False
# 1031133    False
# 1031134    False
# 1031135    False
# Name: User-ID, Length: 1031136, dtype: bool

# %%
ratings_with_bookname[ratings_with_bookname['User-ID'].isin(y)]
# Out:
#          User-ID        ISBN  Book-Rating  \
# 2           6543  034545104X            0
# 5          23768  034545104X            0
# 7          28523  034545104X            0
# 15         77940  034545104X            0
# 16         81977  034545104X            0
# ...          ...         ...          ...
# 1030883   275970  1880837927            0
# 1030884   275970  188717897X            0
# 1030885   275970  1888889047            0
# 1030886   275970  1931868123            0
# 1030887   275970  3411086211           10
#
#                                                 Book-Title  \
# 2                                     Flesh Tones: A Novel
# 5                                     Flesh Tones: A Novel
# 7                                     Flesh Tones: A Novel
# 15                                    Flesh Tones: A Novel
# 16                                    Flesh Tones: A Novel
# ...                                                    ...
# ...

# %%
filtered_rating = ratings_with_bookname[ratings_with_bookname['User-ID'].isin(y)]

# %%
filtered_rating
# Out:
#          User-ID        ISBN  Book-Rating  \
# 2           6543  034545104X            0
# 5          23768  034545104X            0
# 7          28523  034545104X            0
# 15         77940  034545104X            0
# 16         81977  034545104X            0
# ...          ...         ...          ...
# 1030883   275970  1880837927            0
# 1030884   275970  188717897X            0
# 1030885   275970  1888889047            0
# 1030886   275970  1931868123            0
# 1030887   275970  3411086211           10
#
#                                                 Book-Title  \
# 2                                     Flesh Tones: A Novel
# 5                                     Flesh Tones: A Novel
# 7                                     Flesh Tones: A Novel
# 15                                    Flesh Tones: A Novel
# 16                                    Flesh Tones: A Novel
# ...                                                    ...
# ...

# %%
filtered_rating.groupby('Book-Title').count()['Book-Rating']
# Out:
# Book-Title
#  A Light in the Storm: The Civil War Diary of Amelia Martin, Fenwick Island, Delaware, 1861 (Dear America)    2
#  Always Have Popsicles                                                                                        1
#  Apple Magic (The Collector's series)                                                                         1
#  Beyond IBM: Leadership Marketing and Finance for the 1990s                                                   1
#  Clifford Visita El Hospital (Clifford El Gran Perro Colorado)                                                1
#                                                                                                              ..
# Ã?Â?ber das Fernsehen.                                                                                        2
# Ã?Â?ber die Pflicht zum Ungehorsam gegen den Staat.                                                           3
# ...

# %%
filtered_rating.groupby('Book-Title').count()['Book-Rating'] >=50
# Out:
# Book-Title
#  A Light in the Storm: The Civil War Diary of Amelia Martin, Fenwick Island, Delaware, 1861 (Dear America)    False
#  Always Have Popsicles                                                                                        False
#  Apple Magic (The Collector's series)                                                                         False
#  Beyond IBM: Leadership Marketing and Finance for the 1990s                                                   False
#  Clifford Visita El Hospital (Clifford El Gran Perro Colorado)                                                False
#                                                                                                               ...
# Ã?Â?ber das Fernsehen.                                                                                        False
# Ã?Â?ber die Pflicht zum Ungehorsam gegen den Staat.                                                           False
# ...

# %%
z = filtered_rating.groupby('Book-Title').count()['Book-Rating'] >=50

# %%
z[z]
# Out:
# Book-Title
# 1984                                                                 True
# 1st to Die: A Novel                                                  True
# 2nd Chance                                                           True
# 4 Blondes                                                            True
# A Bend in the Road                                                   True
#                                                                      ...
# Year of Wonders                                                      True
# You Belong To Me                                                     True
# Zen and the Art of Motorcycle Maintenance: An Inquiry into Values    True
# Zoya                                                                 True
# \O\" Is for Outlaw"                                                  True
# Name: Book-Rating, Length: 706, dtype: bool

# %%
famous_books = z[z].index

# %%
famous_books
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Day Late and a Dollar Short', 'A Fine Balance',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='Book-Title', length=706)

# %%
filtered_rating['Book-Title'].isin(famous_books)
# Out:
# 2          False
# 5          False
# 7          False
# 15         False
# 16         False
#            ...
# 1030883    False
# 1030884    False
# 1030885    False
# 1030886    False
# 1030887    False
# Name: Book-Title, Length: 474007, dtype: bool

# %%
filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]
# Out:
#          User-ID        ISBN  Book-Rating              Book-Title  \
# 63        278418  0446520802            0            The Notebook
# 65          3363  0446520802            0            The Notebook
# 66          7158  0446520802           10            The Notebook
# 69         11676  0446520802           10            The Notebook
# 74         23768  0446520802            6            The Notebook
# ...          ...         ...          ...                     ...
# 1026724   266865  0531001725           10  The Catcher in the Rye
# 1027923   269566  0670809381            0                  Echoes
# 1028777   271284  0440910927            0           The Rainmaker
# 1029070   271705  B0001PIOX4            0          Fahrenheit 451
# 1030868   275970  1586210661            9  Me Talk Pretty One Day
#
#                    Book-Author Year-Of-Publication                Publisher  \
# 63             Nicholas Sparks                1996             Warner Books
# ...

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
final_ratings
# Out:
#          User-ID        ISBN  Book-Rating              Book-Title  \
# 63        278418  0446520802            0            The Notebook
# 65          3363  0446520802            0            The Notebook
# 66          7158  0446520802           10            The Notebook
# 69         11676  0446520802           10            The Notebook
# 74         23768  0446520802            6            The Notebook
# ...          ...         ...          ...                     ...
# 1026724   266865  0531001725           10  The Catcher in the Rye
# 1027923   269566  0670809381            0                  Echoes
# 1028777   271284  0440910927            0           The Rainmaker
# 1029070   271705  B0001PIOX4            0          Fahrenheit 451
# 1030868   275970  1586210661            9  Me Talk Pretty One Day
#
#                    Book-Author Year-Of-Publication                Publisher  \
# 63             Nicholas Sparks                1996             Warner Books
# ...

# %%
final_ratings.drop_duplicates()
# Out:
#          User-ID        ISBN  Book-Rating              Book-Title  \
# 63        278418  0446520802            0            The Notebook
# 65          3363  0446520802            0            The Notebook
# 66          7158  0446520802           10            The Notebook
# 69         11676  0446520802           10            The Notebook
# 74         23768  0446520802            6            The Notebook
# ...          ...         ...          ...                     ...
# 1026724   266865  0531001725           10  The Catcher in the Rye
# 1027923   269566  0670809381            0                  Echoes
# 1028777   271284  0440910927            0           The Rainmaker
# 1029070   271705  B0001PIOX4            0          Fahrenheit 451
# 1030868   275970  1586210661            9  Me Talk Pretty One Day
#
#                    Book-Author Year-Of-Publication                Publisher  \
# 63             Nicholas Sparks                1996             Warner Books
# ...

# %%
final_ratings.pivot_table(index = 'Book-Title', columns = 'User-ID', values = 'Book-Rating')
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
pt = final_ratings.pivot_table(index = 'Book-Title', columns = 'User-ID', values = 'Book-Rating')

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
pt.fillna(0, inplace=True)

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_similarity(pt)
# Out:
# array([[1.        , 0.10255025, 0.01220856, ..., 0.12110367, 0.07347567,
#         0.04316046],
#        [0.10255025, 1.        , 0.2364573 , ..., 0.07446129, 0.16773875,
#         0.14263397],
#        [0.01220856, 0.2364573 , 1.        , ..., 0.04558758, 0.04938579,
#         0.10796119],
#        ...,
#        [0.12110367, 0.07446129, 0.04558758, ..., 1.        , 0.07085128,
#         0.0196177 ],
#        [0.07347567, 0.16773875, 0.04938579, ..., 0.07085128, 1.        ,
#         0.10602962],
#        [0.04316046, 0.14263397, 0.10796119, ..., 0.0196177 , 0.10602962,
#         1.        ]])

# %%
cosine_similarity(pt).shape
# Out:
# (706, 706)

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores
# Out:
# array([[1.        , 0.10255025, 0.01220856, ..., 0.12110367, 0.07347567,
#         0.04316046],
#        [0.10255025, 1.        , 0.2364573 , ..., 0.07446129, 0.16773875,
#         0.14263397],
#        [0.01220856, 0.2364573 , 1.        , ..., 0.04558758, 0.04938579,
#         0.10796119],
#        ...,
#        [0.12110367, 0.07446129, 0.04558758, ..., 1.        , 0.07085128,
#         0.0196177 ],
#        [0.07347567, 0.16773875, 0.04938579, ..., 0.07085128, 1.        ,
#         0.10602962],
#        [0.04316046, 0.14263397, 0.10796119, ..., 0.0196177 , 0.10602962,
#         1.        ]])

# %%
similarity_scores.shape
# Out:
# (706, 706)

# %%
def recommend(book_name):
  # fetch index
  return suggestions

# %%
np.where(pt.index=='4 Blondes')
# Out:
# (array([3]),)

# %%
np.where(pt.index=='4 Blondes')[0][0]
# Out:
# 3

# %%
def recommend(book_name):
  # fetch index
  index = np.where(pt.index== book_name)[0][0]
  distances = similarity_scores[index]
  return suggestions

# %%
similarity_scores[3]
# Out:
# array([0.        , 0.        , 0.        , 1.        , 0.        ,
#        0.11158235, 0.        , 0.        , 0.07439555, 0.        ,
#        0.        , 0.14576203, 0.05499338, 0.        , 0.        ,
#        0.        , 0.        , 0.04289816, 0.        , 0.11215379,
#        0.        , 0.        , 0.02473898, 0.        , 0.0254068 ,
#        0.12305174, 0.        , 0.        , 0.        , 0.        ,
#        0.09381049, 0.        , 0.06859607, 0.        , 0.0779401 ,
#        0.03771542, 0.08134518, 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.05477141, 0.        , 0.05958855,
#        0.        , 0.        , 0.07684047, 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.        , 0.06703391,
#        0.        , 0.        , 0.03245271, 0.        , 0.0408861 ,
#        0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.0094036 , 0.        , 0.        , 0.00939554, 0.        ,
# ...

# %%
list(enumerate(similarity_scores[0]))
# Out:
# [(0, 0.9999999999999999),
#  (1, 0.10255024829874465),
#  (2, 0.012208555646509366),
#  (3, 0.0),
#  (4, 0.053672244225442485),
#  (5, 0.027749013024662858),
#  (6, 0.08216491130000354),
#  (7, 0.13732869060263378),
#  (8, 0.03261686350494277),
#  (9, 0.03667590746512177),
#  (10, 0.02322418425912186),
#  (11, 0.06766486753662343),
#  (12, 0.020839782065795794),
#  (13, 0.09673734976610586),
#  (14, 0.13388864701187034),
#  (15, 0.08303111691811028),
#  (16, 0.1115354275858341),
#  (17, 0.05100410510067514),
#  (18, 0.025177841632809915),
#  (19, 0.11706383185253948),
#  (20, 0.0),
#  (21, 0.14333792815336935),
#  (22, 0.07847534327232125),
#  (23, 0.06150451339525138),
#  (24, 0.08723968326958673),
#  (25, 0.0),
#  (26, 0.07009814362931202),
#  (27, 0.13658680855472938),
#  (28, 0.07600327535501016),
#  (29, 0.12167133598776536),
#  (30, 0.007680459111722776),
#  (31, 0.01473221255132234),
#  (32, 0.0),
#  (33, 0.07965814289647455),
#  (34, 0.04522616573040869),
# ...

# %%
list(enumerate(similarity_scores[3]))
# Out:
# [(0, 0.0),
#  (1, 0.0),
#  (2, 0.0),
#  (3, 1.0),
#  (4, 0.0),
#  (5, 0.11158234783062482),
#  (6, 0.0),
#  (7, 0.0),
#  (8, 0.07439555056493442),
#  (9, 0.0),
#  (10, 0.0),
#  (11, 0.14576203341012606),
#  (12, 0.05499338389911775),
#  (13, 0.0),
#  (14, 0.0),
#  (15, 0.0),
#  (16, 0.0),
#  (17, 0.042898160366533294),
#  (18, 0.0),
#  (19, 0.11215378957501862),
#  (20, 0.0),
#  (21, 0.0),
#  (22, 0.024738980596645314),
#  (23, 0.0),
#  (24, 0.02540679568643376),
#  (25, 0.12305173578602326),
#  (26, 0.0),
#  (27, 0.0),
#  (28, 0.0),
#  (29, 0.0),
#  (30, 0.093810493917375),
#  (31, 0.0),
#  (32, 0.06859607433155815),
#  (33, 0.0),
#  (34, 0.07794009648081775),
#  (35, 0.03771541627007571),
#  (36, 0.08134518347820842),
#  (37, 0.0),
#  (38, 0.0),
#  (39, 0.0),
#  (40, 0.0),
#  (41, 0.0),
#  (42, 0.05477141171610637),
#  (43, 0.0),
#  (44, 0.05958854548495317),
#  (45, 0.0),
#  (46, 0.0),
#  (47, 0.076840468344349),
#  (48, 0.0),
#  (49, 0.0),
#  (50, 0.0),
#  (51, 0.0),
# ...

# %%
sorted(list(enumerate(similarity_scores[0])), key = lambda x:x[1])
# Out:
# [(3, 0.0),
#  (20, 0.0),
#  (25, 0.0),
#  (32, 0.0),
#  (52, 0.0),
#  (55, 0.0),
#  (61, 0.0),
#  (67, 0.0),
#  (70, 0.0),
#  (71, 0.0),
#  (72, 0.0),
#  (83, 0.0),
#  (91, 0.0),
#  (99, 0.0),
#  (105, 0.0),
#  (115, 0.0),
#  (132, 0.0),
#  (133, 0.0),
#  (134, 0.0),
#  (138, 0.0),
#  (142, 0.0),
#  (143, 0.0),
#  (146, 0.0),
#  (157, 0.0),
#  (161, 0.0),
#  (173, 0.0),
#  (176, 0.0),
#  (179, 0.0),
#  (191, 0.0),
#  (201, 0.0),
#  (210, 0.0),
#  (222, 0.0),
#  (223, 0.0),
#  (237, 0.0),
#  (246, 0.0),
#  (248, 0.0),
#  (263, 0.0),
#  (266, 0.0),
#  (273, 0.0),
#  (274, 0.0),
#  (287, 0.0),
#  (290, 0.0),
#  (308, 0.0),
#  (311, 0.0),
#  (315, 0.0),
#  (335, 0.0),
#  (336, 0.0),
#  (340, 0.0),
#  (351, 0.0),
#  (356, 0.0),
#  (367, 0.0),
#  (375, 0.0),
#  (378, 0.0),
#  (388, 0.0),
#  (390, 0.0),
#  (391, 0.0),
#  (399, 0.0),
#  (403, 0.0),
#  (405, 0.0),
#  (408, 0.0),
#  (428, 0.0),
#  (433, 0.0),
#  (449, 0.0),
#  (451, 0.0),
#  (452, 0.0),
#  (455, 0.0),
#  (456, 0.0),
# ...

# %%
sorted(list(enumerate(similarity_scores[0])), key = lambda x:x[1], reverse=True)
# Out:
# [(0, 0.9999999999999999),
#  (47, 0.2702651417103732),
#  (545, 0.2639619371123496),
#  (82, 0.2366937434740099),
#  (634, 0.23299389358170397),
#  (551, 0.2262639743141286),
#  (181, 0.22222254415660225),
#  (500, 0.21057743765309012),
#  (344, 0.20675540390454),
#  (554, 0.20025063706783053),
#  (520, 0.19972624710300058),
#  (527, 0.19656287691544358),
#  (488, 0.19511819825564608),
#  (552, 0.1920889620576415),
#  (318, 0.19182230688281934),
#  (624, 0.18925313707609975),
#  (598, 0.18921367782346202),
#  (60, 0.18908176672188648),
#  (622, 0.18571699439818884),
#  (647, 0.1841081817659337),
#  (546, 0.18408910419891056),
#  (202, 0.18049207281616433),
#  (541, 0.17990898085771034),
#  (309, 0.17415730924332484),
#  (588, 0.1738182944100774),
#  (537, 0.17008719986228352),
#  (544, 0.1672877700938274),
#  (66, 0.16566734565340113),
#  (118, 0.165272766123669),
#  (269, 0.1650329228149958),
#  (354, 0.16337845332530374),
#  (476, 0.16104067376144765),
# ...

# %%
sorted(list(enumerate(similarity_scores[0])), key = lambda x:x[1], reverse=True)[1:7]
# Out:
# [(47, 0.2702651417103732),
#  (545, 0.2639619371123496),
#  (82, 0.2366937434740099),
#  (634, 0.23299389358170397),
#  (551, 0.2262639743141286),
#  (181, 0.22222254415660225)]

# %%
def recommend(book_name):
  # fetch index
  index = np.where(pt.index== book_name)[0][0]
  similar_items = sorted(list(enumerate(similarity_scores[0])), key = lambda x:x[1], reverse=True)[1:7]

  for i in similar_items:
    print(i[0])

# %%
recommend('1984')
# Out:
# 47
# 545
# 82
# 634
# 551
# 181

# %%
def recommend(book_name):
  # fetch index
  index = np.where(pt.index== book_name)[0][0]
  similar_items = sorted(list(enumerate(similarity_scores[index])), key = lambda x:x[1], reverse=True)[1:7]

  for i in similar_items:
    print(i[0])

# %%
recommend('4 Blondes')
# Out:
# 553
# 389
# 378
# 420
# 358
# 88

# %%
def recommend(book_name):
  # fetch index
  index = np.where(pt.index== book_name)[0][0]
  similar_items = sorted(list(enumerate(similarity_scores[index])), key = lambda x:x[1], reverse=True)[1:7]

  for i in similar_items:
    print(pt.index[i[0]])

# %%
recommend('1984')
# Out:
# Animal Farm
# The Handmaid's Tale
# Brave New World
# The Vampire Lestat (Vampire Chronicles, Book II)
# The Hours : A Novel
# Fahrenheit 451

# %%
recommend('Harry Potter and the Chamber of Secrets (Book 2)')
# Out:
# Harry Potter and the Prisoner of Azkaban (Book 3)
# Harry Potter and the Goblet of Fire (Book 4)
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))
# Harry Potter and the Sorcerer's Stone (Book 1)
# Harry Potter and the Order of the Phoenix (Book 5)
# Charlotte's Web (Trophy Newbery)

# %%
import pickle
pickle.dump(popular_df, open('popularbooks.pkl', 'wb'))

# %%
def recommend(book_name):
  # fetch index
  index = np.where(pt.index== book_name)[0][0]
  similar_items = sorted(list(enumerate(similarity_scores[index])), key = lambda x:x[1], reverse=True)[1:7]

  for i in similar_items:
    print(books[books['Book-Title'] == pt.index[i[0]]])

# %%
recommend('Harry Potter and the Chamber of Secrets (Book 2)')
# Out:
#              ISBN                                         Book-Title  \
# 3839   0439136350  Harry Potter and the Prisoner of Azkaban (Book 3)
# 6330   0439136369  Harry Potter and the Prisoner of Azkaban (Book 3)
# 85245  0786222743  Harry Potter and the Prisoner of Azkaban (Book 3)
#
#          Book-Author Year-Of-Publication        Publisher  \
# 3839   J. K. Rowling                1999       Scholastic
# 6330   J. K. Rowling                2001       Scholastic
# 85245  J. K. Rowling                2000  Thorndike Press
#
#                                              Image-URL-S  \
# 3839   http://images.amazon.com/images/P/0439136350.0...
# 6330   http://images.amazon.com/images/P/0439136369.0...
# 85245  http://images.amazon.com/images/P/0786222743.0...
#
#                                              Image-URL-M  \
# 3839   http://images.amazon.com/images/P/0439136350.0...
# 6330   http://images.amazon.com/images/P/0439136369.0...
# ...

# %%
def recommend(book_name):
  # fetch index
  index = np.where(pt.index== book_name)[0][0]
  similar_items = sorted(list(enumerate(similarity_scores[index])), key = lambda x:x[1], reverse=True)[1:7]

  for i in similar_items:
    temp_df = books[books['Book-Title'] == pt.index[i[0]]]
    print(temp_df.drop_duplicates('Book-Title')['Book-Author'])

# %%
recommend('Harry Potter and the Chamber of Secrets (Book 2)')
# Out:
# 3839    J. K. Rowling
# Name: Book-Author, dtype: object
# 5431    J. K. Rowling
# Name: Book-Author, dtype: object
# 2143    J. K. Rowling
# Name: Book-Author, dtype: object
# 2809    J. K. Rowling
# Name: Book-Author, dtype: object
# 5506    J. K. Rowling
# Name: Book-Author, dtype: object
# 3847    E. B. White
# Name: Book-Author, dtype: object

# %%
def recommend(book_name):
  # fetch index
  index = np.where(pt.index== book_name)[0][0]
  similar_items = sorted(list(enumerate(similarity_scores[index])), key = lambda x:x[1], reverse=True)[1:7]

  data = []
  for i in similar_items:
    item = []
    temp_df = books[books['Book-Title'] == pt.index[i[0]]]
    item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
    item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
    item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))

    data.append(item)

  return data

# %%
recommend('Harry Potter and the Chamber of Secrets (Book 2)')
# Out:
# [['Harry Potter and the Prisoner of Azkaban (Book 3)',
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/0439136350.01.MZZZZZZZ.jpg'],
#  ['Harry Potter and the Goblet of Fire (Book 4)',
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/0439139597.01.MZZZZZZZ.jpg'],
#  ["Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))",
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/059035342X.01.MZZZZZZZ.jpg'],
#  ["Harry Potter and the Sorcerer's Stone (Book 1)",
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/0590353403.01.MZZZZZZZ.jpg'],
#  ['Harry Potter and the Order of the Phoenix (Book 5)',
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/043935806X.01.MZZZZZZZ.jpg'],
#  ["Charlotte's Web (Trophy Newbery)",
#   'E. B. White',
#   'http://images.amazon.com/images/P/0064400557.01.MZZZZZZZ.jpg']]

# %%
pickle.dump(pt, open('pt.pkl', 'wb'))
pickle.dump(books, open('books.pkl', 'wb'))
pickle.dump(similarity_scores, open('similarityscores.pkl', 'wb'))
